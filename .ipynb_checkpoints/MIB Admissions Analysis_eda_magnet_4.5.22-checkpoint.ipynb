# %%
'''Clear out temporary variables and get a clean session'''
try:
    from IPython import get_ipython
    get_ipython().magic('clear')
    get_ipython().magic('reset -f')
except:
    pass

# %%
'''Import necessary libraries'''
import pandas as pd
import numpy as np
import os
import glob
import re
import math

import missingno as msno
import pickle
import bz2

import sklearn
from sklearn.model_selection import GridSearchCV, RepeatedStratifiedKFold, train_test_split, RandomizedSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.metrics import classification_report, roc_auc_score
from sklearn.preprocessing import OrdinalEncoder, StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.impute import SimpleImputer,KNNImputer
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn import set_config
from pca import pca
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, silhouette_samples, adjusted_rand_score

import seaborn as sns
from scipy.stats import skew, skewtest

import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

# %%
'''Open pickled file'''
with open('mib_final_combine.pkl', 'rb') as f:
    df = pickle.load(f)

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %%
'''Create separate dataframes for magnet and ib'''
ib_df = df.loc[df['program_IB'] == 1]
magnet_df = df.loc[df['program_Magnet'] == 1]

# %%
df.columns
plot_list = ['program_admit','essay_raw', 'math_raw', 'gpa_raw','standard_ela', 'recommend', 'interview']

# %%
'''Create Silhouette and Centroid plots'''

def kmeans_evaluation(X, cluster_range):
    for n_cluster in cluster_range:
        fig, (ax1, ax2) = plt.subplots(1,2, figsize = (10,5))
        ax1.set_xlim([-.1, 1])
        ax1.set_ylim([0, len(X) + (n_cluster+1) * 10])

        clusterer = KMeans(n_clusters = n_cluster, init = 'k-means++', n_init = 300, max_iter = 500, random_state = 42)
        cluster_labels = clusterer.fit_predict(X)

        silhouette_avg = silhouette_score(X, cluster_labels)
        print('For number of clusters = :', n_cluster, "The average silhouette score is ", silhouette_avg)

        sample_sil_values = silhouette_samples(X, cluster_labels)

        '''Sihouette Plots'''
        y_lower = 10
        for i in range(n_cluster):
            ith_sil_value = sample_sil_values[cluster_labels == i]
            ith_sil_value.sort()

            size_cluster_i = ith_sil_value.shape[0]
            y_upper = y_lower + size_cluster_i

            color = cm.nipy_spectral(float(i)/n_cluster)
            ax1.fill_betweenx(
            np.arange(y_lower, y_upper), 
                0,
                ith_sil_value,
                facecolor = color,
                edgecolor = color,
                alpha = .7
            )

            ax1.text(-.5, y_lower + .5 * size_cluster_i, str(i))
            y_lower = y_upper +10

            ax1.set_title('Silhouette plot for various clusters')
            ax1.set_xlabel('Silhouette coefficient values')
            ax1.set_ylabel('Cluster label')

            ax1.axvline(x=silhouette_avg, color = 'r', linestyle = '--')

            ax1.set_yticks([])
            ax1.set_xticks([-.1,0,.2,.4,.6,.8,1])

            '''Cluster plots'''
            color = cm.nipy_spectral(cluster_labels.astype(float)/n_cluster)
            ax2.scatter(X.iloc[:, 0], X.iloc[:, 1], marker = '.', s=30, lw=0, alpha=.7, c=color, edgecolor = 'k')

            centers = clusterer.cluster_centers_
            ax2.scatter(
                centers[:, 0],
                centers[:, 1],
                marker = 'o',
                c='white',
                alpha = 1,
                s=200,
                edgecolor = 'k'
            )

            for i, c in enumerate(centers):
                ax2.scatter(c[0], c[1], marker = '$%d$' %i, alpha=1, s=50, edgecolor = 'k')

            ax2.set_title('Visualization of clustered data')
            ax2.set_xlabel('Feature space for 1st feature')
            ax2.set_ylabel('Feature space for 2nd feature')

            plt.suptitle(
                'Silhouette analysis for KMeans clustering on sample data with n_clusters = %d'
                % n_cluster,
                fontsize = 14,
                fontweight = 'bold'
            )

# %%
def qq_plot (df):
    for column in df.columns:
        print(column)
        sm.qqplot(df[column], line ='s', fit = True)

# %%
'''Create pariplots to show relationships between variables - Magnet'''
sns.pairplot(magnet_df[plot_list], kind = 'scatter', hue = 'program_admit', corner = True)

# %%
'''Correlation Heatmap - Magnet'''
df_corr_magnet = magnet_df[plot_list].corr()
matrix = pd.DataFrame(np.tril(df_corr_magnet), columns = df_corr_magnet.columns).replace(0, np.nan)
matrix.set_index(df_corr_magnet.columns, drop = True, inplace = True)
sns.heatmap(matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
'''Create pariplots to show relationships between variables'''
sns.pairplot(df[plot_list], kind = 'scatter', hue = 'program_admit', corner = True)

# %%
'''Correlation Heatmap for both programs'''
df_corr = df[plot_list].corr()
matrix = pd.DataFrame(np.tril(df_corr), columns = df_corr.columns).replace(0, np.nan)
matrix.set_index(df_corr.columns, drop = True, inplace = True)
sns.heatmap(matrix, annot=True)
# Out:
# <AxesSubplot:>

# %%
'''Function to perform PCA analysis'''

'''Split data into test and train IB'''
def conduct_pca(df, pca_list, n_components):
    X = df[pca_list].drop(pca_list[0], axis = 1)
    y = df[pca_list[0]].astype('int32')

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .25, stratify = y, random_state=42)
    
    '''Create PCA model'''
    pca = PCA(n_components = n_components)
    pca.fit(X_train, y_train)
    
    '''Find cumulative variance of components'''
    cum_variance = np.cumsum(pca.explained_variance_ratio_*100)
    variance = pca.explained_variance_ratio_*100

    '''Print explained variance with all factors'''
    print(f'Cumulative variance explained by model {cum_variance}')
    print(f'The explained variance for each factor is: {variance}')
    
    '''Create Scree Plot'''
    PC_values = np.arange(pca.n_components_) + 1
    plt.plot(PC_values, pca.explained_variance_ratio_, 'ro-', linewidth=2)
    plt.title('Scree Plot')
    plt.xlabel('Principal Component')
    plt.ylabel('Proportion of Variance Explained')
    plt.xticks(np.arange(1,6,1));

    return pca, X, y, X_train, X_test, y_train, y_test

# %%
'''Function to draw PCA biplot retreived from: 
https://stackoverflow.com/questions/39216897/plot-pca-loadings-and-loading-in-biplot-in-sklearn-like-rs-autoplot'''

def myplot(score, coeff, y, labels = None):
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]
    scalex = 1.0/(xs.max() - xs.min())
    scaley = 1.0/(ys.max() - ys.min())

    plt.scatter(xs * scalex, ys * scaley, c=y)

    for i in range(n):
        plt.arrow(0, 0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
        if labels is None:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'g', ha = 'center', va = 'center')
        else:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'g', ha = 'center', va = 'center')
    plt.xlim(-1,1)
    plt.ylim(-1,1)
    plt.xlabel("PC{}".format(1))
    plt.ylabel("PC{}".format(2))
    plt.grid()

# %% [markdown]
# ### Magnet PCA Analysis - With Interview

# %%
msno.matrix(magnet_df)
# Out:
# <AxesSubplot:>

# %%
magnet_df_interview = magnet_df.dropna(how = 'any')

# %%
magnet_df_interview
# Out:
#       program_IB  admit_decision_ax  admit_decision_rj  \
# 43             0                  0                  1
# 44             0                  0                  1
# 45             0                  1                  0
# 46             0                  1                  0
# 47             0                  1                  0
# ...          ...                ...                ...
# 1479           0                  1                  0
# 1480           0                  1                  0
# 1481           0                  1                  0
# 1482           0                  1                  0
# 1483           0                  1                  0
#
#       admit_offer_accepted_no  admit_offer_accepted_yes   gpa_raw  \
# 43                          1                         0  0.257922
# 44                          1                         0 -1.716773
# 45                          1                         0  1.411485
# 46                          0                         1  1.883783
# 47                          0                         1  0.602581
# ...                       ...                       ...       ...
# 1479                        0                         1 -1.103042
# 1480                        0                         1 -0.459086
# 1481                        0                         1  1.162900
# 1482                        0                         1 -0.288928
# 1483                        0                         1 -0.229770
#
#       gpa_converted  gpa_weighted  recommend  recommend_converted  ...  \
# 43        -0.073822      0.953495  -1.074991            -0.866074  ...
# 44        -1.415286     -0.409731  -0.869429            -0.677768  ...
# 45         1.658246      2.512815   1.498323             1.367772  ...
# 46         1.658246      2.512815   1.324729             1.223645  ...
# 47         0.743211      1.709849   0.525293             0.549662  ...
# ...             ...           ...        ...                  ...  ...
# 1479      -0.903344     -1.004848  -1.356025            -1.356025  ...
# 1480      -0.098901     -0.623163  -0.905660            -0.905660  ...
# 1481       0.826505     -0.235047   1.337066             1.337066  ...
# 1482      -0.098901     -0.623163  -1.172320            -1.172320  ...
# 1483      -0.098901     -0.623163  -0.029178            -0.029178  ...
#
#       interview_converted  interview_weighted  admit_score  \
# 43              -2.065961           -1.576862    -1.592431
# 44              -2.065961           -1.576862    -1.632763
# 45              -2.065961           -1.576862     1.307310
# 46              -0.658551           -1.282089     1.849077
# 47               0.281382           -1.126989     0.498953
# ...                   ...                 ...          ...
# 1479             0.939978            0.057821    -0.116312
# 1480            -0.862372           -0.915672    -0.161451
# 1481             1.318591            0.237976     0.624853
# 1482            -0.162238           -0.508917     0.153178
# 1483            -0.862372           -0.915672    -0.044455
#
#                 aspen_name           full_name_x similarity     lasid  \
# 43            biro, robert          biro, robert      100.0  20134095
# 44       budd, christopher     budd, christopher      100.0  20132070
# 45           chan, matthew         chan, matthew      100.0    592013
# 46        dougherty, brian      dougherty, brian      100.0  20134440
# 47           eckert, scott         eckert, scott      100.0  20130066
# ...                    ...                   ...        ...       ...
# 1479  nimbvikar, siddharth  nimbvikar, siddharth      100.0  20218311
# 1480         chauhan, mark         chauhan, mark      100.0  20218328
# 1481       reinstein, jack       reinstein, jack      100.0  20218187
# 1482         shah, tanisha         shah, tanisha      100.0  20218255
# 1483       mavani, anjolie       mavani, anjolie      100.0  20218276
#
#                full_name_y                 success_text    program_admit
# 43            biro, robert                 Not Accepted  Magnet-Rejected
# 44       budd, christopher                 Not Accepted  Magnet-Rejected
# 45           chan, matthew  Accepted but did not attend  Magnet-Accepted
# 46        dougherty, brian                 Unsuccessful  Magnet-Accepted
# 47           eckert, scott                 Unsuccessful  Magnet-Accepted
# ...                    ...                          ...              ...
# 1479  nimbvikar, siddharth        Successful Completion  Magnet-Accepted
# 1480         chauhan, mark        Successful Completion  Magnet-Accepted
# 1481       reinstein, jack        Successful Completion  Magnet-Accepted
# 1482         shah, tanisha        Successful Completion  Magnet-Accepted
# 1483       mavani, anjolie        Successful Completion  Magnet-Accepted
#
# [802 rows x 31 columns]

# %%
msno.matrix(magnet_df_interview)
# Out:
# <AxesSubplot:>

# %%
plot_list = ['essay_raw', 'math_raw', 'gpa_raw','standard_ela', 'recommend', 'interview']

fig, ax = plt.subplots(figsize= (15, 10))
sns.boxplot(data = magnet_df_interview[plot_list])
# Out:
# <AxesSubplot:>

# %%
for column in magnet_df_interview[plot_list]:
    print(column, skewtest(magnet_df_interview[column], nan_policy = 'propagate'))
# Out:
# essay_raw SkewtestResult(statistic=-0.6007416841289891, pvalue=0.5480120507136126)
# math_raw SkewtestResult(statistic=-2.227599138217397, pvalue=0.02590725819241189)
# gpa_raw SkewtestResult(statistic=-1.0905676690280128, pvalue=0.2754631623474393)
# standard_ela SkewtestResult(statistic=-1.0447009076792073, pvalue=0.2961612251997774)
# recommend SkewtestResult(statistic=-3.089594130756517, pvalue=0.002004301828343453)
# interview SkewtestResult(statistic=0.5385034582998884, pvalue=0.5902295182187596)

# %%
'''Conduct PCA on Magnet data with 6 components'''
pca_list = ['program_IB','essay_raw', 'math_raw', 'gpa_raw','standard_ela', 'recommend', 'interview']
pca, X, y, X_train, X_test, y_train, y_test = conduct_pca(magnet_df_interview, pca_list, 6)
# Out:
# Cumulative variance explained by model [ 44.62010767  59.70776776  73.82120133  85.8179963   94.785495
#  100.        ]
# The explained variance for each factor is: [44.62010767 15.08766009 14.11343356 11.99679498  8.9674987   5.214505  ]

# %%
'''Conduct PCA on Magnet data with 2 components'''
pca_list = ['program_IB','essay_raw', 'math_raw', 'gpa_raw','standard_ela', 'recommend', 'interview']
pca, X, y, X_train, X_test, y_train, y_test = conduct_pca(magnet_df_interview, pca_list, 2)
# Out:
# Cumulative variance explained by model [44.62010767 59.70776776]
# The explained variance for each factor is: [44.62010767 15.08766009]

# %%
'''Calculate pc loadings - Magnet'''
pd.options.display.float_format = '{:,.4f}'.format
loadings = pd.DataFrame(pca.components_.T, columns=['PC1', 'PC2'], index=X_train.columns)
loadings
# Out:
#                  PC1     PC2
# essay_raw    -0.3324  0.3090
# math_raw     -0.3830 -0.1396
# gpa_raw      -0.4893 -0.2527
# standard_ela -0.4339  0.1371
# recommend    -0.4572 -0.4979
# interview    -0.3257  0.7447

# %%
'''Transform Magnet Data'''
pca_trans = pca.transform(X_test)
pca_trans_df = pd.DataFrame(pca_trans, columns = ['PC1', 'PC2'])

magnet_interview_pca_df = pd.DataFrame(pca.transform(X), columns = ['PC1', 'PC2'])
magnet_interview_pca_df['program_admit'] = magnet_df_interview['program_admit'].values
magnet_interview_pca_df['success_text'] = magnet_df_interview['success_text'].values

# %%
'''Pickle datafile'''
with open('magnet_interview_pca.pkl', 'wb') as f:
    pickle.dump(magnet_interview_pca_df, f)

# %%
'''Plot Primary Components'''
plt.figure(figsize=(10,5))
sns.scatterplot(x = pca_trans[:,0], y = pca_trans[:,1])
plt.xlabel('Component 1')
plt.ylabel('Component 2');

# %%
'''Create biplot for Magnet PCA'''
myplot(pca_trans[:,0:2],np.transpose(pca.components_[0:2, :]), y_test)

# %%
'''Create KMeans model'''
X = magnet_interview_pca_df.drop(['program_admit', 'success_text'], axis = 1)
y = magnet_interview_pca_df['program_admit']

cluster_range = np.arange(2,8)
kmeans_evaluation(X, cluster_range)
# Out:
# For number of clusters = : 2 The average silhouette score is  0.4255149960416075
# For number of clusters = : 3 The average silhouette score is  0.32951144286314427
# For number of clusters = : 4 The average silhouette score is  0.3598045567758237
# For number of clusters = : 5 The average silhouette score is  0.3626980664878686
# For number of clusters = : 6 The average silhouette score is  0.3638174749107031
# For number of clusters = : 7 The average silhouette score is  0.35124835685121475

# %%
'''Plot data against acceptance status'''
fig, ax = plt.subplots(figsize = (15, 10))

color_dict = {}
color_list = ['b', 'orange']
admit_status = pd.Series(list(magnet_interview_pca_df['program_admit']))
for index, status in enumerate(magnet_interview_pca_df['program_admit'].unique()):
    color_dict[status] = color_list[index]

for index, status in enumerate(magnet_interview_pca_df['program_admit'].unique()):
    ix = np.where(magnet_interview_pca_df['program_admit'] == status)
    ax.scatter(x = X['PC1'].to_numpy()[ix], y = X['PC2'].to_numpy()[ix], c = color_dict[status], label = status)
    handles, labels = ax.get_legend_handles_labels()
    ax.legend()

# %%
magnet_interview_pca_df.loc[magnet_interview_pca_df['success_text'] == 'Current Student', 'success_text'] = 'Not Accepted'

# %%
'''Plot data against completion status'''
fig, ax = plt.subplots(figsize = (15, 10))

color_dict = {}
color_list = ['b', 'orange', 'r', 'black', 'yellow']
completion_status = pd.Series(list(magnet_interview_pca_df['success_text']))
for index, status in enumerate(magnet_interview_pca_df['success_text'].unique()):
    color_dict[status] = color_list[index]

for index, status in enumerate(magnet_interview_pca_df['success_text'].unique()):
    ix = np.where(magnet_interview_pca_df['success_text'] == status)
    ax.scatter(x = X['PC1'].to_numpy()[ix], y = X['PC2'].to_numpy()[ix], c = color_dict[status], label = status)
    handles, labels = ax.get_legend_handles_labels()
    ax.legend()

# %% [markdown]
# ### Magnet Analysis - without interview

# %%
magnet_df
# Out:
#       program_IB  admit_decision_ax  admit_decision_rj  \
# 43             0                  0                  1
# 44             0                  0                  1
# 45             0                  1                  0
# 46             0                  1                  0
# 47             0                  1                  0
# ...          ...                ...                ...
# 2709           0                  0                  1
# 2710           0                  0                  1
# 2711           0                  0                  1
# 2712           0                  0                  1
# 2713           0                  0                  1
#
#       admit_offer_accepted_no  admit_offer_accepted_yes  gpa_raw  \
# 43                          1                         0   0.2579
# 44                          1                         0  -1.7168
# 45                          1                         0   1.4115
# 46                          0                         1   1.8838
# 47                          0                         1   0.6026
# ...                       ...                       ...      ...
# 2709                        1                         0   0.8437
# 2710                        1                         0  -0.0615
# 2711                        1                         0  -0.6337
# 2712                        1                         0  -1.8098
# 2713                        1                         0  -2.1862
#
#       gpa_converted  gpa_weighted  recommend  recommend_converted  ...  \
# 43          -0.0738        0.9535    -1.0750              -0.8661  ...
# 44          -1.4153       -0.4097    -0.8694              -0.6778  ...
# 45           1.6582        2.5128     1.4983               1.3678  ...
# 46           1.6582        2.5128     1.3247               1.2236  ...
# 47           0.7432        1.7098     0.5253               0.5497  ...
# ...             ...           ...        ...                  ...  ...
# 2709         1.3860        1.4465     0.4794                  nan  ...
# 2710        -0.5871       -0.4986     0.0189                  nan  ...
# 2711        -0.5871       -0.4986    -0.5905                  nan  ...
# 2712        -1.9657       -1.8605    -0.9450                  nan  ...
# 2713        -1.9657       -1.8605    -1.8338                  nan  ...
#
#       interview_converted  interview_weighted  admit_score  \
# 43                -2.0660             -1.5769      -1.5924
# 44                -2.0660             -1.5769      -1.6328
# 45                -2.0660             -1.5769       1.3073
# 46                -0.6586             -1.2821       1.8491
# 47                 0.2814             -1.1270       0.4990
# ...                   ...                 ...          ...
# 2709                  nan                 nan       1.4751
# 2710                  nan                 nan      -0.2145
# 2711                  nan                 nan      -0.7400
# 2712                  nan                 nan      -2.1721
# 2713                  nan                 nan      -2.2267
#
#                   aspen_name          full_name_x similarity     lasid  \
# 43              biro, robert         biro, robert   100.0000  20134095
# 44         budd, christopher    budd, christopher   100.0000  20132070
# 45             chan, matthew        chan, matthew   100.0000    592013
# 46          dougherty, brian     dougherty, brian   100.0000  20134440
# 47             eckert, scott        eckert, scott   100.0000  20130066
# ...                      ...                  ...        ...       ...
# 2709              lin, derek  murupudi, deekshita    63.0000         0
# 2710           chauhan, mark       chauhan, megan    81.0000         0
# 2711  colon trujillo, jeremy        binag, jeremy    86.0000         0
# 2712         yeung, jeanette            yeung, zi    86.0000         0
# 2713           ramesh, akhil         beere, akhil    72.0000         0
#
#                  full_name_y                 success_text    program_admit
# 43              biro, robert                 Not Accepted  Magnet-Rejected
# 44         budd, christopher                 Not Accepted  Magnet-Rejected
# 45             chan, matthew  Accepted but did not attend  Magnet-Accepted
# 46          dougherty, brian                 Unsuccessful  Magnet-Accepted
# 47             eckert, scott                 Unsuccessful  Magnet-Accepted
# ...                      ...                          ...              ...
# 2709              lin, derek                 Not Accepted  Magnet-Rejected
# 2710           chauhan, mark                 Not Accepted  Magnet-Rejected
# 2711  colon trujillo, jeremy                 Not Accepted  Magnet-Rejected
# 2712         yeung, jeanette                 Not Accepted  Magnet-Rejected
# 2713           ramesh, akhil                 Not Accepted  Magnet-Rejected
#
# [1667 rows x 31 columns]

# %%
msno.matrix(magnet_df)
# Out:
# <AxesSubplot:>

# %%
magnet_df['essay_raw'].fillna(magnet_df['essay_raw'].mean(), inplace = True)
magnet_df['standard_ela'].fillna(magnet_df['standard_ela'].mean(), inplace = True)
drop_list = ['recommend_converted', 'interview', 'interview_converted', 'interview_weighted',\
            'essay_converted', 'essay_weighted']
magnet_no_interview = magnet_df.drop(drop_list, axis = 1)
# Out:
# C:\Users\scott\anaconda3\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
msno.matrix(magnet_no_interview)
# Out:
# <AxesSubplot:>

# %%
'''KNN impute missing math_raw scores'''
columns = ['program_IB', 'admit_decision_ax', 'admit_decision_rj', 'admit_offer_accepted_no', 'admit_offer_accepted_yes', 
           'gpa_raw', 'gpa_converted', 'gpa_weighted', 'recommend', 'recommend_weighted', 
           'standard_ela','program_Magnet', 'math_raw', 'math_converted', 'math_weighted', 'admit_score']

X = pd.DataFrame(magnet_no_interview[columns])

imputer = KNNImputer(n_neighbors=2)
imputed = imputer.fit_transform(X)
df_imputed = pd.DataFrame(imputed, columns = columns)

magnet_no_interview['math_raw'] = df_imputed['math_raw'].values
msno.matrix(magnet_no_interview)
# Out:
# <AxesSubplot:>

# %%
'''Pickle datafile'''
with open('magnet_ml_df.pkl', 'wb') as f:
    pickle.dump(magnet_no_interview, f)

# %%
'''Conduct PCA on Magnet data with 5 components'''
pca_list = ['program_IB', 'math_raw', 'gpa_raw', 'recommend', 'essay_raw', 'standard_ela']
pca, X, y, X_train, X_test, y_train, y_test = conduct_pca(magnet_no_interview, pca_list, 5)
# Out:
# Cumulative variance explained by model [ 49.86050714  66.61133403  80.96946191  91.77807913 100.        ]
# The explained variance for each factor is: [49.86050714 16.75082688 14.35812789 10.80861722  8.22192087]

# %%
'''Conduct PCA on Magnet data with 2 components'''
pca_list = ['program_IB', 'math_raw', 'gpa_raw', 'recommend', 'essay_raw', 'standard_ela']
pca, X, y, X_train, X_test, y_train, y_test = conduct_pca(magnet_no_interview, pca_list, 2)
# Out:
# Cumulative variance explained by model [49.86050714 66.61133403]
# The explained variance for each factor is: [49.86050714 16.75082688]

# %%
'''Calculate pc loadings - Magnet'''
pd.options.display.float_format = '{:,.4f}'.format
loadings = pd.DataFrame(pca.components_.T, columns=['PC1', 'PC2'], index=X_train.columns)
loadings
# Out:
#                  PC1     PC2
# math_raw     -0.4316 -0.1166
# gpa_raw      -0.5571 -0.1823
# recommend    -0.5249 -0.4008
# essay_raw    -0.3036  0.8418
# standard_ela -0.3684  0.2896

# %%
'''Transform Magnet Data'''
pca_trans = pca.transform(X_test)
pca_trans_df = pd.DataFrame(pca_trans, columns = ['PC1', 'PC2'])

magnet_no_interview_pca_df = pd.DataFrame(pca.transform(X), columns = ['PC1', 'PC2'])
magnet_no_interview_pca_df['program_admit'] = magnet_no_interview['program_admit'].values
magnet_no_interview_pca_df['success_text'] = magnet_no_interview['success_text'].values

# %%
'''Pickle datafile'''
with open('magnet_no_interview_pca.pkl', 'wb') as f:
    pickle.dump(magnet_no_interview_pca_df, f)

# %%
'''Create biplot for Magnet PCA'''
myplot(pca_trans[:,0:2],np.transpose(pca.components_[0:2, :]), y_test)

# %%
'''Create KMeans model'''
X = magnet_no_interview_pca_df.drop(['program_admit', 'success_text'], axis = 1)
y = magnet_no_interview_pca_df['program_admit']

cluster_range = np.arange(2,8)
kmeans_evaluation(X, cluster_range)
# Out:
# For number of clusters = : 2 The average silhouette score is  0.41771393647023985
# For number of clusters = : 3 The average silhouette score is  0.3352883758155525
# For number of clusters = : 4 The average silhouette score is  0.3216050859537921
# For number of clusters = : 5 The average silhouette score is  0.33091022870379266
# For number of clusters = : 6 The average silhouette score is  0.3426855962440797
# For number of clusters = : 7 The average silhouette score is  0.3510560427733292

# %%
'''Plot data against acceptance status'''
fig, ax = plt.subplots(figsize = (15, 10))

color_dict = {}
color_list = ['b', 'orange']
admit_status = pd.Series(list(magnet_no_interview_pca_df['program_admit']))
for index, status in enumerate(magnet_no_interview_pca_df['program_admit'].unique()):
    color_dict[status] = color_list[index]

for index, status in enumerate(magnet_no_interview_pca_df['program_admit'].unique()):
    ix = np.where(magnet_no_interview_pca_df['program_admit'] == status)
    ax.scatter(x = X['PC1'].to_numpy()[ix], y = X['PC2'].to_numpy()[ix], c = color_dict[status], label = status)
    handles, labels = ax.get_legend_handles_labels()
    ax.legend()

# %%
'''Plot data against completion status'''
fig, ax = plt.subplots(figsize = (15, 10))

color_dict = {}
color_list = ['b', 'orange', 'r', 'black', 'green']
completion_status = pd.Series(list(magnet_no_interview_pca_df['success_text']))
for index, status in enumerate(magnet_no_interview_pca_df['success_text'].unique()):
    color_dict[status] = color_list[index]

for index, status in enumerate(magnet_no_interview_pca_df['success_text'].unique()):
    ix = np.where(magnet_no_interview_pca_df['success_text'] == status)
    ax.scatter(x = X['PC1'].to_numpy()[ix], y = X['PC2'].to_numpy()[ix], c = color_dict[status], label = status, alpha = .7)
    handles, labels = ax.get_legend_handles_labels()
    ax.legend()
